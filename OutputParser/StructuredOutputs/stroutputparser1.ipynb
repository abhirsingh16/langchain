# %%
# !pip install -q transformers langchain langchain-huggingface huggingface_hub
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.1/102.1 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.0/475.0 kB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.3/157.3 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.8/411.8 kB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.7/343.7 kB 30.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.9/193.9 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.3/136.3 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.3/208.3 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 109.3 MB/s eta 0:00:00

# %%
from huggingface_hub import login

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
MODEL_ID = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

# %%
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

# %%
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    device_map = 'auto',
    trust_remote_code =True
)
# Out:
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
gen_pipeline = pipeline(
    model = MODEL_ID,
    task = 'text-generation',
    max_new_tokens = 500,
    temperature=0.6

)
# Out:
# Device set to use cpu

# %%
llm = HuggingFacePipeline(pipeline = gen_pipeline)

# %%
chat_model = ChatHuggingFace(llm = llm)

# %%
template1 = PromptTemplate(
    template = "Write detailed report on {topic}",
    input_variable = ['topic']
)

template2 = PromptTemplate(
    template = 'Write a five line summary on the following text \n {text}',
    input_variables=['text']
)

# %%
parser = StrOutputParser()

# %%
chain = template1 | chat_model | parser | template2 | chat_model | parser

# %%
result = chain.invoke({'topic': 'AI'})

# %%
print(result)
# Out:
# <|user|>
# Write a five line summary on the following text
#  <|user|>
# Write detailed report on AI</s>
# <|assistant|>
# Introduction
# Artificial Intelligence (AI) has been rapidly advancing in recent years, with increasing applications in various industries. The potential benefits of AI include enhanced decision-making, improved customer service, and more efficient operations. However, AI can also pose significant risks, such as job displacement, data privacy concerns, and potential conflicts with human values and culture. In this report, we will examine the current state of AI and its potential impact on various industries, as well as the challenges and opportunities associated with AI adoption.
#
# Current State of AI
# The current state of AI is characterized by rapid advancement and increasing popularity. The largest companies in the world, such as Google, Amazon, and Facebook, have been investing heavily in AI for years. The adoption rate is also increasing, with many small and medium-sized businesses adopting AI for various purposes. AI technologies include machine learning, natural language processing (NLP), computer vision, and robotics.
#
# Machine Learning
# Machine learning is the process of training machine intelligence by collecting and analyzing data. AI technology uses machine learning algorithms to learn from data and make predictions. Machine learning algorithms can be trained on large datasets, allowing them to make accurate predictions in real-time. One example of machine learning is the use of chatbots in customer service. Chatbots can learn from customer feedback and improve their responses over time.
#
# Natural Language Processing (NLP)
# NLP is the application of computer science to natural language. AI technology uses NLP to analyze and understand human language. NLP can be used in various industries, such as customer service, healthcare, and finance. For example, chatbots can use NLP to understand customer inquiries, respond to queries, and provide personalized recommendations.
#
# Computer Vision
# Computer vision is the application of computer science to image and video processing. AI technology uses computer vision to recognize objects, detect faces, and analyze images. Some examples of AI applications in the retail industry include facial recognition, which allows customers to purchase products with a single scan.
#
# Robotics
# Robotics is the application of robotics technology to create intelligent machines. AI technology uses robotics to perform tasks, such as assembly, cleaning</s>
# <|assistant|>
# Chapter 1: Current State of AI
#
# Introduction:
# Artificial Intelligence (AI) has been rapidly advancing in recent years, with increasing applications in various industries. This chapter provides an overview of the current state of AI and its potential impact on various industries.
#
# 1.1. Current State of AI: The Big Four
# The Big Four - Google, Amazon, Facebook, and Apple - are among the largest companies in the world that have been investing heavily in AI for years. These companies are utilizing AI technologies in various ways, including machine learning, natural language processing (NLP), computer vision, and robotics.
#
# 1.2. Machine Learning
# Machine learning is the process of training machine intelligence by collecting and analyzing data. AI technology uses machine learning algorithms to learn from data and make predictions. Machine learning algorithms can be trained on large datasets, allowing them to make accurate predictions in real-time.
#
# 1.3. Natural Language Processing (NLP)
# Natural Language Processing (NLP) is the application of computer science to natural language. AI technology uses NLP to analyze and understand human language. NLP can be used in various industries, such as customer service, healthcare, and finance. For example, chatbots can use NLP to understand customer inquiries, respond to queries, and provide personalized recommendations.
#
# 1.4. Computer Vision
# Computer Vision is the application of computer science to image and video processing. AI technology uses computer vision to recognize objects, detect faces, and analyze images. Some examples of AI applications in the retail industry include facial recognition, which allows customers to purchase products with a single scan.
#
# 1.5. Robotics
# Robotics is the application of robotics technology to create intelligent machines. AI technology uses robotics to perform tasks, such as assembly, cleaning, and manufacturing. Robotics has the potential to revolutionize various industries, such as manufacturing, healthcare, and construction.
#
# 1.6. Challenges and Opportunities
# The current state of AI presents both challenges and opportunities. Challenges include the risk of job displacement, data privacy concerns, and potential conflicts with human values and culture. On the other hand

# %%
print(result.title)
# Out:
# <built-in method title of str object at 0x3ebe9c30>
